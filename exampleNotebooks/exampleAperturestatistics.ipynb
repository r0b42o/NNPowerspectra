# %%
import g3lhalo
import pyccl as ccl
import matplotlib.pyplot as plt
import numpy as np

# %%
# %pip install ../
# %pip install scipy
# %pip install camb
# Out:
# Processing /Users/robin/Desktop/BA/G3LHalo_python
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from g3lhalo==0.0.1) (1.22.4)
# Building wheels for collected packages: g3lhalo
#   Building wheel for g3lhalo (setup.py) ... done
#   Created wheel for g3lhalo: filename=g3lhalo-0.0.1-py3-none-any.whl size=23050 sha256=2325282c792428e60b7d1ffa689b7105d2c1b5640bba092e5516070da27c7fb7
#   Stored in directory: /private/var/folders/xj/w3hmc6jx17n3jjfcz2d8ssmw0000gn/T/pip-ephem-wheel-cache-0gh8tq1m/wheels/5f/23/2a/48bd38a4aa86d49e80ece1f3b5567944e122ceb182babf946c
# Successfully built g3lhalo
# Installing collected packages: g3lhalo
#   Attempting uninstall: g3lhalo
#     Found existing installation: g3lhalo 0.0.1
#     Uninstalling g3lhalo-0.0.1:
#       Successfully uninstalled g3lhalo-0.0.1
# Successfully installed g3lhalo-0.0.1
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scipy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (1.13.1)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from scipy) (1.22.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: camb in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (1.5.9)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from camb) (1.22.4)
# Requirement already satisfied: scipy>=1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from camb) (1.13.1)
# Requirement already satisfied: sympy>=1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from camb) (1.13.3)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from camb) (21.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from sympy>=1.0->camb) (1.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from packaging->camb) (3.0.9)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Example for Aperture Statistics

# %% [markdown]
# We show here how to calculate the aperture statistics

# %%
# Cosmology
cosmo = {
    'Om_c': 0.28,
    'Om_b': 0.05,
    'h': 0.67,
    'sigma_8': 0.8,
    'n_s': 0.96
}

# Halo mass function
hmf=ccl.halos.MassFuncSheth99()

# Halo bias
hbf=ccl.halos.HaloBiasSheth01()

# Concentration mass Relation
cmfunc=ccl.halos.ConcentrationDuffy08()


# HOD
# HOD parameters
alpha=1
sigma=0.2
Mth=1e12
Mprime=20*Mth
beta=1

# Correlation between galaxy populations
A=0 # 0 ==> No correlation between populations
epsilon=0

# Scaling of halo profile concentration
flens=1 # 1 ==> Same as dark matter

# Get HOD
hod_cen, hod_sat = g3lhalo.HOD_Zheng(alpha, Mth, sigma, Mprime, beta)

# Define model
model = g3lhalo.halomodel(verbose=True, cosmo=cosmo, hmfunc=hmf, hbfunc=hbf, cmfunc=cmfunc)
model.set_hods(hod_cen, hod_sat, A=A, epsilon=epsilon, flens1=flens, flens2=flens)
# Out:
# Setting cosmology
# Om_c: 0.28
# Om_b: 0.05
# h: 0.67
# sigma_8: 0.8
# n_s: 0.96
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation

# %%
zs=np.linspace(0.2, 1.5)

n_sources=np.exp(-(zs-1)**2/0.02**2)
n_lenses=np.exp(-(zs-0.5)**2/0.02**2)

n_sources/=(np.sum(n_sources)*(zs[1]-zs[0]))
n_lenses/=(np.sum(n_lenses)*(zs[1]-zs[0]))

# %%
plt.plot(zs, n_sources, label="sources")

plt.plot(zs, n_lenses, label='lenses')


plt.legend()
plt.xlabel(r"Redshift $z$")
plt.ylabel(r"$n(z)$")
# Out:
# Text(0, 0.5, '$n(z)$')

# %%
projection=g3lhalo.projectedSpectra(model)

projection.set_nz_lenses(zs, n_lenses)
projection.set_nz_sources(zs, n_sources)

# %%
# Precompute power spectra

ells=np.geomspace(1, 20000, 20)

# convergence-convergence
C_kk_1h, C_kk_2h, C_kk=projection.C_kk(ells)

C_kk_dict={
    'ell': ells,
    'ps': C_kk
}

# convergence-galaxies
C_kg_1h, C_kg_2h, C_kg=projection.C_kg(ells, 1)

C_kg_dict={
    'ell': ells,
    'ps': C_kg
}

# galaxies-galaxies
C_gg_1h, C_gg_2h, C_gg=projection.C_gg(ells, 1, 1)

C_gg_dict={
    'ell': ells,
    'ps': C_gg
}

# %%
thetas=np.geomspace(2, 200, 10)

# %%
# Aperture statistics: Map2

Map2_calculator = g3lhalo.apertureStatistics(powerspec=C_kk_dict)
Map2=[]

for th in thetas:
    th_rad=np.deg2rad(th/60)
    Map2.append(Map2_calculator.second_order(th_rad))

# %%
# Aperture statistics: MapNap

MapNap_calculator = g3lhalo.apertureStatistics(powerspec=C_kg_dict)
MapNap=[]

for th in thetas:
    th_rad=np.deg2rad(th/60)
    MapNap.append(MapNap_calculator.second_order(th_rad))

# %%
# Aperture statistics: NapNap

NapNap_calculator = g3lhalo.apertureStatistics(powerspec=C_gg_dict)
NapNap=[]

for th in thetas:
    th_rad=np.deg2rad(th/60)
    NapNap.append(NapNap_calculator.second_order(th_rad))

# %%
plt.loglog(thetas, Map2, label='MM')
plt.loglog(thetas, MapNap, label='MN')
plt.loglog(thetas, NapNap, label='NN')

# %%
# Precompute bi spectra

ells1=np.geomspace(1, 20000, 20)
ells2=np.geomspace(1, 20000, 20)
phis=np.linspace(0, 2*np.pi, 20)

# matter-galaxy-galaxy

Bs_kgg=np.zeros((len(ells1), len(ells2), len(phis)))
for i, ell1 in enumerate(ells1):
    for j, ell2 in enumerate(ells2):
        for k, phi in enumerate(phis):

            ell3=np.sqrt(ell1**2+ell2**2+2*np.cos(phi)*ell1*ell2)

            B1h, B2h, B3h, B=projection.C_kgg(ell1, ell2, ell3, 1, 1)
            Bs_kgg[i, j, k]=B


B_kgg_dict={
    'ell1': ells1,
    'ell2': ells2,
    'phi': phis, 
    'bs': Bs_kgg
}
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 16
#      12         for k, phi in enumerate(phis):
#      14             ell3=np.sqrt(ell1**2+ell2**2+2*np.cos(phi)*ell1*ell2)
# ---> 16             B1h, B2h, B3h, B=projection.C_kgg(ell1, ell2, ell3, 1, 1)
#      17             Bs_kgg[i, j, k]=B
#      20 B_kgg_dict={
#      21     'ell1': ells1,
#      22     'ell2': ells2,
#      23     'phi': phis,
#      24     'bs': Bs_kgg
#      25 }
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/g3lhalo/projectedSpectra.py:212, in projectedSpectra.C_kgg(self, ell1, ell2, ell3, type1, type2)
#     209 delta_z = self.deltaZs[i]
#     211 # Calculate the halo contributions for the current redshift
# --> 212 P1h, P2h, P3h, _ = self.halomod.source_lens_lens_bs(
#     213     ell1 / w, ell2 / w, ell3 / w, z, type1, type2
#     214 )
#     216 # Compute the scaling factor
#     217 weight = self.gs[i] * (self.n_l(z)**2) / (w**3 * self.dwdz[i])
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/g3lhalo/halomodel.py:678, in halomodel.source_lens_lens_bs(self, k1, k2, k3, z, type1, type2, mmin, mmax)
#     668 rho_bar = ccl.rho_x(self.cosmo, 1 / (1 + z), "matter")
#     670 One_halo = (
#     671     self.source_lens_lens_bs_1h(k1, k2, k3, z, type1, type2, mmin, mmax)
#     672     / n1
#     673     / n2
#     674     / rho_bar
#     675 )
#     677 Two_halo = (
# --> 678     self.source_lens_lens_bs_2h(k1, k2, k3, z, type1, type2, mmin, mmax)
#     679     / n1
#     680     / n2
#     681     / rho_bar
#     682 )
#     684 Three_halo = (
#     685     self.source_lens_lens_bs_3h(k1, k2, k3, z, type1, type2, mmin, mmax)
#     686     / n1
#     687     / n2
#     688     / rho_bar
#     689 )
#     691 return One_halo, Two_halo, Three_halo, One_halo + Two_halo + Three_halo
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/g3lhalo/halomodel.py:580, in halomodel.source_lens_lens_bs_2h(self, k1, k2, k3, z, type1, type2, mmin, mmax)
#     573 summand1 = np.trapz(kernel(np.geomspace(mmin, mmax, N)), np.geomspace(mmin, mmax, N))
#     575 kernel = (
#     576     lambda m: self.dndm(m, z)
#     577     * self.G_ab(k2, k3, m, z, type1, type2)
#     578     * self.bh(m, z)
#     579 )
# --> 580 summand1 *= np.trapz(kernel(np.geomspace(mmin, mmax, N)), np.geomspace(mmin, mmax, N))
#     582 summand1 *= self.pk_lin(k3, z)
#     584 kernel = lambda m: self.dndm(m, z) * self.G_a(k2, m, z, type1) * self.bh(m, z)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/g3lhalo/halomodel.py:576, in halomodel.source_lens_lens_bs_2h.<locals>.<lambda>(m)
#     570 kernel = (
#     571     lambda m: self.dndm(m, z) * self.u_NFW(k1, m, z, 1.0) * m * self.bh(m, z)
#     572 )
#     573 summand1 = np.trapz(kernel(np.geomspace(mmin, mmax, N)), np.geomspace(mmin, mmax, N))
#     575 kernel = (
# --> 576     lambda m: self.dndm(m, z)
#     577     * self.G_ab(k2, k3, m, z, type1, type2)
#     578     * self.bh(m, z)
#     579 )
#     580 summand1 *= np.trapz(kernel(np.geomspace(mmin, mmax, N)), np.geomspace(mmin, mmax, N))
#     582 summand1 *= self.pk_lin(k3, z)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/g3lhalo/halomodel.py:80, in halomodel.set_hmf.<locals>.<lambda>(m, z)
#      77 if self.verbose:
#      78     print("Setting halo mass function")
# ---> 80 self.dndm = lambda m, z: hmfunc(self.cosmo, m, 1.0 / (1.0 + z)) / (
#      81     m * np.log(10)
#      82 )
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pyccl/halos/halo_model_base.py:193, in MassFunc.__call__(self, cosmo, M, a)
#     181 """ Returns the mass function for input parameters.
#     182
#     183 Args:
#    (...)
#     190         :math:`dn/d\\log_{10}M` in units of Mpc^-3 (comoving).
#     191 """
#     192 M_use = np.atleast_1d(M)
# --> 193 logM, sigM, dlns_dlogM = self._get_logM_sigM(
#     194     cosmo, M_use, a, return_dlns=True)
#     196 rho = (const.RHO_CRITICAL * cosmo['Omega_m'] * cosmo['h']**2)
#     197 f = self._get_fsigma(cosmo, sigM, a, 2.302585092994046 * logM)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pyccl/halos/halo_model_base.py:125, in HMIngredients._get_logM_sigM(self, cosmo, M, a, return_dlns)
#     122     return logM, sigM
#     124 # dlogsigma(M)/dlog10(M)
# --> 125 dlns_dlogM, status = lib.dlnsigM_dlogM_vec(cosmo.cosmo, a, logM,
#     126                                            len(logM), status)
#     127 check(status, cosmo=cosmo)
#     128 return logM, sigM, dlns_dlogM
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pyccl/ccllib.py:1406, in dlnsigM_dlogM_vec(cosmo, a, logM, nout, status)
#    1402 if numpy.shape(logM) != (nout,):
#    1403     raise CCLError("Input shape for `halo_mass` must match `(nout,)`!")
# -> 1406 return _ccllib.dlnsigM_dlogM_vec(cosmo, a, logM, nout, status)
#
# KeyboardInterrupt:

# %%
# Aperture statistics: MapNapNap
thetas=np.geomspace(2, 200, 10)



MapNapNap_calculator = g3lhalo.apertureStatistics(bispec=B_kgg_dict)
MapNapNap=[]

for th in thetas:
    print(th)
    th_rad=np.deg2rad(th/60)
    MapNapNap.append(MapNapNap_calculator.third_order(th_rad, th_rad, th_rad))
# Out:
# 2.0
# 3.3362010744001167
# 5.565118804414249
# 9.283177667225555
# 15.485273653622542
# 25.830993300297685
# 43.08869380063767
# 71.87627327609252
# 119.8968500637882
# 200.0

# %%
plt.loglog(thetas, MapNapNap)

# %%
# matter-matter-galaxy

Bs_kkg=np.zeros((len(ells1), len(ells2), len(phis)))
for i, ell1 in enumerate(ells1):
    for j, ell2 in enumerate(ells2):
        for k, phi in enumerate(phis):

            ell3=np.sqrt(ell1**2+ell2**2+2*np.cos(phi)*ell1*ell2)

            B1h, B2h, B3h, B=projection.C_kkg(ell1, ell2, ell3, 1)
            Bs_kkg[i, j, k]=B

B_kkg_dict={
    'ell1': ells1,
    'ell2': ells2,
    'phi': phis, 
    'bs': Bs_kgg
}

# %%
# Aperture statistics: MapMapNap

MapMapNap_calculator = g3lhalo.apertureStatistics(bispec=B_kkg_dict)
MapMapNap=[]

for th in thetas:
    th_rad=np.deg2rad(th/60)
    MapMapNap.append(MapMapNap_calculator.third_order(th_rad, th_rad, th_rad))

# %%
plt.loglog(thetas, MapMapNap, label='MMN')
plt.loglog(thetas, MapNapNap, label='MNN')

# %%
# Precompute bi spectra

ells1=np.geomspace(1, 20000, 20)
ells2=np.geomspace(1, 20000, 20)
phis=np.linspace(0, 2*np.pi, 20)

# matter-matter-matter

Bs_kkk=np.zeros((len(ells1), len(ells2), len(phis)))
for i, ell1 in enumerate(ells1):
    for j, ell2 in enumerate(ells2):
        for k, phi in enumerate(phis):

            ell3=np.sqrt(ell1**2+ell2**2+2*np.cos(phi)*ell1*ell2)

            B1h, B2h, B3h, B=projection.C_kkk(ell1, ell2, ell3)
            Bs_kgg[i, j, k]=B


B_kkk_dict={
    'ell1': ells1,
    'ell2': ells2,
    'phi': phis, 
    'bs': Bs_kgg
}

# %%
# Aperture statistics: MapMapMap

MapMapMap_calculator = g3lhalo.apertureStatistics(bispec=B_kkk_dict)
MapMapMap=[]

for th in thetas:
    th_rad=np.deg2rad(th/60)
    MapMapMap.append(MapMapMap_calculator.third_order(th_rad, th_rad, th_rad))

# %%
plt.loglog(thetas, MapMapNap, label='MMN')
plt.loglog(thetas, MapNapNap, label='MNN')
plt.loglog(thetas, np.array(MapMapMap), label='MMM')

# %%
plt.plot(thetas, np.array(MapNapNap)/np.array(MapMapMap))
