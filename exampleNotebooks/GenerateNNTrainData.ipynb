# %% [markdown]
# ## This Notebook calculates the powerspektrum for various diffrent cosmological starting parameters

# %%
import socket
socket.gethostname()
# Out:
# 'euclid.uibk.ac.at'

# %%
import pyccl as ccl
import g3lhalo
import matplotlib.pyplot as plt
import numpy as np
from pyDOE import lhs
import tensorflow as tf
import matplotlib.pyplot as plt
import json
import os
from datetime import datetime
# Out:
# 2025-04-22 12:24:40.585454: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-22 12:24:41.677495: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-22 12:24:42.529037: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-22 12:24:42.529971: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-22 12:24:54.326704: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#%pip install pyDOE
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyDOE in /home/rhoffmann/.local/lib/python3.10/site-packages (0.3.8)
# Requirement already satisfied: numpy in /home/rhoffmann/.local/lib/python3.10/site-packages (from pyDOE) (1.24.3)
# Requirement already satisfied: scipy in /home/rhoffmann/.local/lib/python3.10/site-packages (from pyDOE) (1.15.2)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# checking that we are using a GPU
device = 'gpu:0' if tf.test.is_gpu_available() else 'cpu'
print('using', device, 'device \n')
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_1672384/3121495569.py:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# using cpu device

# %%
# setting the seed for reproducibility
np.random.seed(9721)
tf.random.set_seed(9721)

# %% [markdown]
# ## Calculating dataset

# %%
N_total = 50000
num_params = 10

data_array = np.empty((N_total, num_params), dtype=object)

Mth_min = 1e10
Mth_max = 1e15
# Definiere die Intervalle für die kosmologischen Parameter
param_intervals = {
    'Om_c': (0.1, 0.6),
    'Om_b': (0.04, 0.06),
    'h': (0.64, 0.82),
    'sigma_8': (0.8, 1),
    'n_s': (0.84, 1.1),
    'alpha': (0, 1),
    'sigma': (0.01, 1),
    'Mth': (Mth_min, Mth_max),
    'Mprime': (Mth_min * 1, Mth_max * 100),
    'beta': (0.1, 2)
}

# Anzahl der Parameter (Dimensionen des LHS)
num_cosmo_params = len(param_intervals)

# Generiere Latin Hypercube Samples (LHS)
lhs_samples = lhs(num_cosmo_params, samples=N_total)

# Skaliere die LHS-Samples auf die jeweiligen Intervalle
cosmo_samples = []
for sample in lhs_samples:
    cosmo = {
        key: param_intervals[key][0] + (param_intervals[key][1] - param_intervals[key][0]) * sample[i]
        for i, key in enumerate(param_intervals)
    }
    cosmo_samples.append(cosmo)

# Halo mass function
hmf = ccl.halos.MassFuncSheth99()

# Halo bias
hbf = ccl.halos.HaloBiasSheth01()

# Concentration mass Relation
cmfunc = ccl.halos.ConcentrationDuffy08()

# Korrelation zwischen Galaxienpopulationen
A = 0  # 0 ==> Keine Korrelation zwischen Populationen
epsilon = 0

# Skalierung des Halo-Profils
flens = 1  # 1 ==> Gleiches Profil wie dunkle Materie

data_array = []

Pk_ss_1h = [1] * 50  # Platzhalter für die 50 Werte
Pk_ss_2h = [2] * 50
Pk_ss = [3] * 50
Pk_sl_1h = [4] * 50
Pk_sl_2h = [5] * 50
Pk_sl = [6] * 50
Pk_ll_1h = [7] * 50
Pk_ll_2h = [8] * 50
Pk_ll = [9] * 50
Pk_lin = [10] * 50

# Hauptschleife für Simulationen
for i in range(N_total):
    # Kosmologische Parameter aus LHS entnehmen
    cosmo = cosmo_samples[i]
    cosmo_array = np.array(list(cosmo.values()))

    # Nur die 5 kosmologischen Parameter für das Modell extrahieren
    cosmo_subset = {
        key: cosmo[key] for key in ['Om_c', 'Om_b', 'h', 'sigma_8', 'n_s']
    }

    # HOD-Parameter extrahieren
    alpha = cosmo['alpha']
    sigma = cosmo['sigma']
    Mth = cosmo['Mth']
    Mprime = cosmo['Mprime']
    beta = cosmo['beta']


    # HOD abrufen
    hod_cen, hod_sat = g3lhalo.HOD_Zheng(alpha, Mth, sigma, Mprime, beta)

    # Modell definieren
    model = g3lhalo.halomodel(verbose=True, cosmo=cosmo_subset, hmfunc=hmf, hbfunc=hbf, cmfunc=cmfunc)
    model.set_hods(hod_cen, hod_sat, A=A, epsilon=epsilon, flens1=flens, flens2=flens)

    # Berechnungen durchführen
    ks = np.geomspace(1e-2, 1e2)
    z = 0

    # Lineares Materie-Leistungsspektrum
    Pk_lin = model.pk_lin(ks, z)

    # Materie-Materie Leistungsspektrum
    Pk_ss_1h, Pk_ss_2h, Pk_ss = model.source_source_ps(ks, z)

    # Materie-Galaxie Leistungsspektrum
    Pk_sl_1h, Pk_sl_2h, Pk_sl = model.source_lens_ps(ks, z, type=1)

    # Galaxie-Galaxie Leistungsspektrum
    Pk_ll_1h, Pk_ll_2h, Pk_ll = model.lens_lens_ps(ks, z, type1=1, type2=1)
    

    # Erstelle das Dictionary mit den Daten für das aktuelle Sample
    data_dict = {
        'Pk_ss_1h': Pk_ss_1h,
        'Pk_ss_2h': Pk_ss_2h,
        'Pk_ss': Pk_ss,
        'Pk_sl_1h': Pk_sl_1h,
        'Pk_sl_2h': Pk_sl_2h,
        'Pk_sl': Pk_sl,
        'Pk_ll_1h': Pk_ll_1h,
        'Pk_ll_2h': Pk_ll_2h,
        'Pk_ll': Pk_ll,
        'Pk_lin': Pk_lin,
    }
    
    # Füge das Dictionary für dieses Sample der Liste hinzu
    data_array.append(data_dict)

    print(f"Run {i+1}/{N_total} completed")
# Out:
# Setting cosmology
# Om_c: 0.13892533720323125
# Om_b: 0.02221794071928906
# h: 0.704792072349252
# sigma_8: 0.9009708783644712
# n_s: 0.9637751092996931
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 1/10000 completed
# Setting cosmology
# Om_c: 0.152485797525424
# Om_b: 0.019363072099307276
# h: 0.6790845166338463
# sigma_8: 0.9839206177615446
# n_s: 1.0763682429606474
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 2/10000 completed
# Setting cosmology
# Om_c: 0.13424256091119546
# Om_b: 0.021240947012867613
# h: 0.7358118774691687
# sigma_8: 0.9375353490634569
# n_s: 0.9410637691565839
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 3/10000 completed
# Setting cosmology
# Om_c: 0.1967347800902421
# Om_b: 0.0210127689120615
# h: 0.645989054864696
# sigma_8: 0.9391298839694197
# n_s: 0.9215089120328889
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 4/10000 completed
# Setting cosmology
# Om_c: 0.1217959877419676
# Om_b: 0.025473232692452212
# h: 0.7376391549071913
# sigma_8: 0.819414857050303
# n_s: 0.9084049856664131
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 5/10000 completed
# Setting cosmology
# Om_c: 0.24382731614440156
# Om_b: 0.025534879293590086
# h: 0.8141553197982729
# sigma_8: 0.8019925237022207
# n_s: 0.9417568117327003
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 6/10000 completed
# Setting cosmology
# Om_c: 0.1817975994478972
# Om_b: 0.01954566044606036
# h: 0.8027327077590709
# sigma_8: 0.8676410800010278
# n_s: 0.911697353132306
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 7/10000 completed
# Setting cosmology
# Om_c: 0.17216343539653248
# Om_b: 0.02450621348252375
# h: 0.6691235485685647
# sigma_8: 0.833839910478995
# n_s: 0.9840547968972619
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 8/10000 completed
# Setting cosmology
# Om_c: 0.17887155053204973
# Om_b: 0.020165530217228663
# h: 0.7032699353501974
# sigma_8: 0.9432957546459708
# n_s: 1.0663974796405196
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9/10000 completed
# Setting cosmology
# Om_c: 0.2071382278948512
# Om_b: 0.019745139769773587
# h: 0.7747370294721966
# sigma_8: 0.8037574826421304
# n_s: 1.0526116916145556
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 10/10000 completed
# Setting cosmology
# Om_c: 0.24238882711652965
# Om_b: 0.019083770252351497
# h: 0.6413875024394624
# sigma_8: 0.8251407626784786
# n_s: 0.8838049171214803
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 11/10000 completed
# Setting cosmology
# Om_c: 0.19812573559407037
# Om_b: 0.02133060711053919
# h: 0.7044403788184647
# sigma_8: 0.9213121391228014
# n_s: 0.9321424413428253
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 12/10000 completed
# Setting cosmology
# Om_c: 0.054477152837028066
# Om_b: 0.020845429338192063
# h: 0.7507375687420819
# sigma_8: 0.8314461370430258
# n_s: 0.9119289614033786
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 13/10000 completed
# Setting cosmology
# Om_c: 0.06936648338003747
# Om_b: 0.020494587647365167
# h: 0.6768976103729315
# sigma_8: 0.9587647614729661
# n_s: 1.0493133904696657
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 14/10000 completed
# Setting cosmology
# Om_c: 0.19133511852479884
# Om_b: 0.024983057708423965
# h: 0.7008570087481811
# sigma_8: 0.8139478251886487
# n_s: 0.9748730546760117
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 15/10000 completed
# Setting cosmology
# Om_c: 0.10797456879025799
# Om_b: 0.01938685215007911
# h: 0.6992704308370061
# sigma_8: 0.8292793930272462
# n_s: 0.9280310649830311
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 16/10000 completed
# Setting cosmology
# Om_c: 0.24949277439622536
# Om_b: 0.02357080980925373
# h: 0.6934467938167936
# sigma_8: 0.901580396281636
# n_s: 0.9111229643863769
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 17/10000 completed
# Setting cosmology
# Om_c: 0.1694035704917417
# Om_b: 0.02347558161632772
# h: 0.6470182201546122
# sigma_8: 0.888571895293892
# n_s: 0.9933121063788489
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 18/10000 completed
# Setting cosmology
# Om_c: 0.09851557266451946
# Om_b: 0.025236594183751064
# h: 0.7577627974903041
# sigma_8: 0.9491495510496812
# n_s: 1.0736609846784821
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 19/10000 completed
# Setting cosmology
# Om_c: 0.13302176258822485
# Om_b: 0.02199995557564749
# h: 0.6589399006240726
# sigma_8: 0.9071816607923231
# n_s: 0.86881804342109
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 20/10000 completed
# Setting cosmology
# Om_c: 0.09412506248060976
# Om_b: 0.019688936014410748
# h: 0.7890498753647176
# sigma_8: 0.9008071769648647
# n_s: 0.8968425290115576
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 21/10000 completed
# Setting cosmology
# Om_c: 0.11472952480185586
# Om_b: 0.024397809569485902
# h: 0.7660811832991552
# sigma_8: 0.8661522312298153
# n_s: 0.8852202913720693
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 22/10000 completed
# Setting cosmology
# Om_c: 0.07559848990195367
# Om_b: 0.02580855327430236
# h: 0.7267232456342538
# sigma_8: 0.9576946936480863
# n_s: 1.0927674865606292
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 23/10000 completed
# Setting cosmology
# Om_c: 0.07431522886140889
# Om_b: 0.01952135236825098
# h: 0.7396402992003321
# sigma_8: 0.8843442359784128
# n_s: 0.903249723904411
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 24/10000 completed
# Setting cosmology
# Om_c: 0.16262378512876322
# Om_b: 0.023214344809226
# h: 0.6942964928318702
# sigma_8: 0.996617698661563
# n_s: 1.0588513101199082
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 25/10000 completed
# Setting cosmology
# Om_c: 0.13169264999937813
# Om_b: 0.022204724691366917
# h: 0.8035884075245061
# sigma_8: 0.9244601765282293
# n_s: 0.9649708088094764
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 26/10000 completed
# Setting cosmology
# Om_c: 0.19290656209827056
# Om_b: 0.024981117363064465
# h: 0.7075212371202958
# sigma_8: 0.8666136103445369
# n_s: 1.0519208841017242
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 27/10000 completed
# Setting cosmology
# Om_c: 0.17946866441865827
# Om_b: 0.025561327988522845
# h: 0.7430379177456036
# sigma_8: 0.8986748027698219
# n_s: 1.0187279030751966
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 28/10000 completed
# Setting cosmology
# Om_c: 0.1271577909041932
# Om_b: 0.02347719477290019
# h: 0.6872002782378545
# sigma_8: 0.9867613781715735
# n_s: 1.0261434421636766
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 29/10000 completed
# Setting cosmology
# Om_c: 0.24534585684265608
# Om_b: 0.020011100158845885
# h: 0.6731086967283273
# sigma_8: 0.9654472446026215
# n_s: 0.8498956505006603
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 30/10000 completed
# Setting cosmology
# Om_c: 0.24125770973773825
# Om_b: 0.022029867036914414
# h: 0.7700237282630324
# sigma_8: 0.9785997121163387
# n_s: 0.9332070419369652
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 31/10000 completed
# Setting cosmology
# Om_c: 0.11677008235066895
# Om_b: 0.01906203182591391
# h: 0.7516304376320204
# sigma_8: 0.9349666659345975
# n_s: 0.929245576715914
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 32/10000 completed
# Setting cosmology
# Om_c: 0.19113639961317885
# Om_b: 0.020480291210901943
# h: 0.6452914642352503
# sigma_8: 0.8574567853979767
# n_s: 0.9760339772788311
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 33/10000 completed
# Setting cosmology
# Om_c: 0.25080896935711156
# Om_b: 0.023687555793563565
# h: 0.7777136620129629
# sigma_8: 0.9693117203125927
# n_s: 1.0991096064811055
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 34/10000 completed
# Setting cosmology
# Om_c: 0.1746615012389828
# Om_b: 0.024209512267088073
# h: 0.7227282666650192
# sigma_8: 0.866195955955879
# n_s: 1.010127397353437
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 35/10000 completed
# Setting cosmology
# Om_c: 0.2478959868042943
# Om_b: 0.022372986936669722
# h: 0.7940988072566583
# sigma_8: 0.9177595714744767
# n_s: 0.9602727554320154
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 36/10000 completed
# Setting cosmology
# Om_c: 0.2459244342744727
# Om_b: 0.01906691992984472
# h: 0.6804788272602588
# sigma_8: 0.9171628590398
# n_s: 0.9790123675100909
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 37/10000 completed
# Setting cosmology
# Om_c: 0.1347081221851349
# Om_b: 0.023362196233044932
# h: 0.7400667611044309
# sigma_8: 0.800870699702655
# n_s: 0.9894494116259882
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 38/10000 completed
# Setting cosmology
# Om_c: 0.22174101839039573
# Om_b: 0.021700508759173506
# h: 0.695434419346875
# sigma_8: 0.9956040720125348
# n_s: 1.0606764913515203
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 39/10000 completed
# Setting cosmology
# Om_c: 0.24833559786477394
# Om_b: 0.024575548151256333
# h: 0.7016836215823651
# sigma_8: 0.949267360298405
# n_s: 0.9016222809553796
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 40/10000 completed
# Setting cosmology
# Om_c: 0.18983189233544567
# Om_b: 0.02448336509347041
# h: 0.6772871162158225
# sigma_8: 0.8269514956827002
# n_s: 1.0390603883105047
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 41/10000 completed
# Setting cosmology
# Om_c: 0.07336181393989742
# Om_b: 0.023526472033262583
# h: 0.7082274906781295
# sigma_8: 0.9631577797302305
# n_s: 0.9404196819781087
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 42/10000 completed
# Setting cosmology
# Om_c: 0.23197683029688554
# Om_b: 0.025598182315208502
# h: 0.7189407219358322
# sigma_8: 0.9356772677485184
# n_s: 0.9400741152623874
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 43/10000 completed
# Setting cosmology
# Om_c: 0.07951685990854954
# Om_b: 0.026015000297079812
# h: 0.7682891764558377
# sigma_8: 0.8127573727179281
# n_s: 0.9834666348931252
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 44/10000 completed
# Setting cosmology
# Om_c: 0.20048752695434346
# Om_b: 0.024245861336506653
# h: 0.7278666695775525
# sigma_8: 0.892215559175192
# n_s: 1.0637541106703872
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 45/10000 completed
# Setting cosmology
# Om_c: 0.07465269985323165
# Om_b: 0.025641323695368316
# h: 0.7105005918082676
# sigma_8: 0.8484347120713925
# n_s: 1.0421706262316706
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 46/10000 completed
# Setting cosmology
# Om_c: 0.21385101138518714
# Om_b: 0.020604011799472303
# h: 0.7444648132750022
# sigma_8: 0.824720507182236
# n_s: 0.9320721860520473
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 47/10000 completed
# Setting cosmology
# Om_c: 0.2287860710793495
# Om_b: 0.020451704850120482
# h: 0.7601215112081583
# sigma_8: 0.8254901755436304
# n_s: 0.8846395907116412
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 48/10000 completed
# Setting cosmology
# Om_c: 0.07266558240943202
# Om_b: 0.022609216936374184
# h: 0.7198135512483932
# sigma_8: 0.9911612741976122
# n_s: 1.074286255561267
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 49/10000 completed
# Setting cosmology
# Om_c: 0.10037160702130826
# Om_b: 0.02355595411086526
# h: 0.6748498179286966
# sigma_8: 0.9772851728301197
# n_s: 0.8681216871148628
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 50/10000 completed
# Setting cosmology
# Om_c: 0.12519772518253475
# Om_b: 0.01968998897239232
# h: 0.7599293653068665
# sigma_8: 0.8931066368303613
# n_s: 0.879258252898216
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 51/10000 completed
# Setting cosmology
# Om_c: 0.06960248657174925
# Om_b: 0.019702875498767865
# h: 0.7261131021605843
# sigma_8: 0.8629995635688351
# n_s: 1.0406863248951066
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 52/10000 completed
# Setting cosmology
# Om_c: 0.16120776505482162
# Om_b: 0.024471337890241602
# h: 0.8114721931671589
# sigma_8: 0.8428905838253085
# n_s: 1.0281562671862812
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 53/10000 completed
# Setting cosmology
# Om_c: 0.202303441486534
# Om_b: 0.02250749855136739
# h: 0.8079347147341174
# sigma_8: 0.8327606384486244
# n_s: 1.0085248754266019
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 54/10000 completed
# Setting cosmology
# Om_c: 0.10488055100044294
# Om_b: 0.022588147304318927
# h: 0.7549745719206731
# sigma_8: 0.8831889026470168
# n_s: 1.0297935943588317
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 55/10000 completed
# Setting cosmology
# Om_c: 0.08768586653647062
# Om_b: 0.0224436522606755
# h: 0.7338190893876835
# sigma_8: 0.8663243885116417
# n_s: 0.9341594475872381
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 56/10000 completed
# Setting cosmology
# Om_c: 0.08206529217172581
# Om_b: 0.023788112224018672
# h: 0.7220520617127875
# sigma_8: 0.9753234400507184
# n_s: 0.8761525270713457
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 57/10000 completed
# Setting cosmology
# Om_c: 0.059245901996219666
# Om_b: 0.0224687407864059
# h: 0.7738409773029266
# sigma_8: 0.8921420009445674
# n_s: 1.0062342342683084
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 58/10000 completed
# Setting cosmology
# Om_c: 0.13152969665401804
# Om_b: 0.02237637860518577
# h: 0.6811397895170097
# sigma_8: 0.818082008633644
# n_s: 0.8676668616347781
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 59/10000 completed
# Setting cosmology
# Om_c: 0.13897836335553213
# Om_b: 0.02441361588237435
# h: 0.6641269929417374
# sigma_8: 0.8143118287448421
# n_s: 0.9268701686671966
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 60/10000 completed
# Setting cosmology
# Om_c: 0.15602722386998183
# Om_b: 0.022188034173306025
# h: 0.7098386045388173
# sigma_8: 0.8683490345551882
# n_s: 1.0202479146819239
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 61/10000 completed
# Setting cosmology
# Om_c: 0.10634578005408368
# Om_b: 0.020981474745293955
# h: 0.7262967475571258
# sigma_8: 0.8497244877569777
# n_s: 0.9745834584551013
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 62/10000 completed
# Setting cosmology
# Om_c: 0.25125537649713137
# Om_b: 0.02318442053255812
# h: 0.7544816043276055
# sigma_8: 0.9469777925329564
# n_s: 0.9308232709027011
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 63/10000 completed
# Setting cosmology
# Om_c: 0.16621552625774555
# Om_b: 0.01906980696819513
# h: 0.8018585512813253
# sigma_8: 0.9724879878446078
# n_s: 1.064119809935157
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 64/10000 completed
# Setting cosmology
# Om_c: 0.25363089250206583
# Om_b: 0.02566753951233729
# h: 0.744302051006066
# sigma_8: 0.8383246382968818
# n_s: 0.8613519550496497
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 65/10000 completed
# Setting cosmology
# Om_c: 0.16696163425644492
# Om_b: 0.02153061955544245
# h: 0.7791791083949604
# sigma_8: 0.9550181406123053
# n_s: 0.8975337536175243
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 66/10000 completed
# Setting cosmology
# Om_c: 0.16774160657984416
# Om_b: 0.019071874413468914
# h: 0.8048228953512633
# sigma_8: 0.8373326717216891
# n_s: 0.8965079392048948
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 67/10000 completed
# Setting cosmology
# Om_c: 0.20518391286480153
# Om_b: 0.02445054352297048
# h: 0.8198795236586092
# sigma_8: 0.9205001742674754
# n_s: 0.886878475161919
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 68/10000 completed
# Setting cosmology
# Om_c: 0.10835999914907404
# Om_b: 0.023957875176031998
# h: 0.8110615280269072
# sigma_8: 0.8155369373975133
# n_s: 0.8704301116373481
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 69/10000 completed
# Setting cosmology
# Om_c: 0.18316338861423942
# Om_b: 0.020149747463906374
# h: 0.6631984400955033
# sigma_8: 0.9900854008883151
# n_s: 1.0772651842288825
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 70/10000 completed
# Setting cosmology
# Om_c: 0.2525607585911754
# Om_b: 0.026063147973593454
# h: 0.78466113061988
# sigma_8: 0.9185516577444254
# n_s: 1.0091723002853157
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 71/10000 completed
# Setting cosmology
# Om_c: 0.14709211480048884
# Om_b: 0.0246396644057358
# h: 0.6952808506116964
# sigma_8: 0.9702669273830252
# n_s: 0.8584297318667659
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 72/10000 completed
# Setting cosmology
# Om_c: 0.1966725463414084
# Om_b: 0.020713260621904855
# h: 0.6839238098932249
# sigma_8: 0.8885881155345875
# n_s: 0.9724408884748061
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 73/10000 completed
# Setting cosmology
# Om_c: 0.24637872929197613
# Om_b: 0.018770525787869134
# h: 0.8107823468452244
# sigma_8: 0.8137299636335646
# n_s: 1.074673417432719
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 74/10000 completed
# Setting cosmology
# Om_c: 0.24502651563924194
# Om_b: 0.02079134265711525
# h: 0.7962542770433019
# sigma_8: 0.9730112002069479
# n_s: 1.0446254847041916
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 75/10000 completed
# Setting cosmology
# Om_c: 0.14633005204546573
# Om_b: 0.019039597205875156
# h: 0.6663663969001032
# sigma_8: 0.945748415184163
# n_s: 0.8548497903843153
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 76/10000 completed
# Setting cosmology
# Om_c: 0.12166396775071969
# Om_b: 0.02076262401497635
# h: 0.7577165301825471
# sigma_8: 0.8077560634661679
# n_s: 1.087347688251358
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 77/10000 completed
# Setting cosmology
# Om_c: 0.07777997331208428
# Om_b: 0.02303665419341643
# h: 0.7780531001632647
# sigma_8: 0.8620656777828939
# n_s: 1.0935394428615088
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 78/10000 completed
# Setting cosmology
# Om_c: 0.12173421435163141
# Om_b: 0.026053746970971323
# h: 0.7993429222697479
# sigma_8: 0.8432471477898096
# n_s: 0.9669304315848402
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 79/10000 completed
# Setting cosmology
# Om_c: 0.1785887419925123
# Om_b: 0.019764002839842396
# h: 0.6678863132459524
# sigma_8: 0.9804101294980734
# n_s: 0.9284754288507598
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 80/10000 completed
# Setting cosmology
# Om_c: 0.0813099120881985
# Om_b: 0.02532969409376651
# h: 0.640816036437268
# sigma_8: 0.895033976397605
# n_s: 1.0419618672294575
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 81/10000 completed
# Setting cosmology
# Om_c: 0.06476758099896146
# Om_b: 0.022641247387074133
# h: 0.6670401713904786
# sigma_8: 0.8238859323500528
# n_s: 1.0094128895161476
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 82/10000 completed
# Setting cosmology
# Om_c: 0.14523007503777835
# Om_b: 0.020819067552008602
# h: 0.6709080288885445
# sigma_8: 0.8785026293078563
# n_s: 0.8801644528963831
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 83/10000 completed
# Setting cosmology
# Om_c: 0.07364359100125509
# Om_b: 0.019345853037450997
# h: 0.6632741325139725
# sigma_8: 0.9849511285226638
# n_s: 0.8414219558919489
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 84/10000 completed
# Setting cosmology
# Om_c: 0.13953634624687217
# Om_b: 0.022828148901139142
# h: 0.6438790991489679
# sigma_8: 0.883260373115801
# n_s: 1.0794689778186122
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 85/10000 completed
# Setting cosmology
# Om_c: 0.2360798485801503
# Om_b: 0.022011173134803694
# h: 0.7299101789694256
# sigma_8: 0.9429517072588788
# n_s: 1.0144511481593022
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 86/10000 completed
# Setting cosmology
# Om_c: 0.08272577442062931
# Om_b: 0.026003171643483314
# h: 0.7632402767532032
# sigma_8: 0.8808008176625077
# n_s: 0.8947390315764111
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 87/10000 completed
# Setting cosmology
# Om_c: 0.07239545514206926
# Om_b: 0.019107266637200956
# h: 0.7802054571459534
# sigma_8: 0.8148680961441497
# n_s: 0.8730732117379649
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 88/10000 completed
# Setting cosmology
# Om_c: 0.20429302078017025
# Om_b: 0.02203670386985371
# h: 0.7480510245805694
# sigma_8: 0.9083773861837722
# n_s: 0.9434173687626922
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 89/10000 completed
# Setting cosmology
# Om_c: 0.24000234409950633
# Om_b: 0.02124523348035952
# h: 0.7636141897652315
# sigma_8: 0.900406697307794
# n_s: 0.8461853302044262
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 90/10000 completed
# Setting cosmology
# Om_c: 0.09958705925824725
# Om_b: 0.025047074889703147
# h: 0.7295756636544221
# sigma_8: 0.9022770802871115
# n_s: 1.0031714035249013
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 91/10000 completed
# Setting cosmology
# Om_c: 0.18140417095706568
# Om_b: 0.024848046672749924
# h: 0.8027395343056072
# sigma_8: 0.9263738458783706
# n_s: 0.9453153547515761
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 92/10000 completed
# Setting cosmology
# Om_c: 0.22971879929157474
# Om_b: 0.021414138555940716
# h: 0.7646238837257524
# sigma_8: 0.8817516596451246
# n_s: 0.9653349362362598
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 93/10000 completed
# Setting cosmology
# Om_c: 0.17402710896998574
# Om_b: 0.021184176505099087
# h: 0.7388772416007621
# sigma_8: 0.9955153029945951
# n_s: 0.9484089625711489
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 94/10000 completed
# Setting cosmology
# Om_c: 0.13768655100893032
# Om_b: 0.025452214520243238
# h: 0.8150364153428713
# sigma_8: 0.9990366216098412
# n_s: 0.9224725987474277
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 95/10000 completed
# Setting cosmology
# Om_c: 0.24243991900060324
# Om_b: 0.026064381176596936
# h: 0.6674529179892229
# sigma_8: 0.8209019945698561
# n_s: 0.8429553645666595
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 96/10000 completed
# Setting cosmology
# Om_c: 0.228288193769552
# Om_b: 0.024171977058590238
# h: 0.6459267237372727
# sigma_8: 0.9701842261773523
# n_s: 0.8927173045954345
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 97/10000 completed
# Setting cosmology
# Om_c: 0.1160768393920531
# Om_b: 0.022061254799495632
# h: 0.7487113131750929
# sigma_8: 0.8961275035895903
# n_s: 1.0130514057234141
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 98/10000 completed
# Setting cosmology
# Om_c: 0.14117187737250866
# Om_b: 0.024159837206972234
# h: 0.7625246102236973
# sigma_8: 0.8519894246853836
# n_s: 0.8774148490624751
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 99/10000 completed
# Setting cosmology
# Om_c: 0.11257819964416525
# Om_b: 0.021918313918852895
# h: 0.709482456667667
# sigma_8: 0.8369154336346095
# n_s: 1.0786655775665612
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 100/10000 completed
# Setting cosmology
# Om_c: 0.19579419952712884
# Om_b: 0.026125099041662513
# h: 0.6744199458369228
# sigma_8: 0.8698872698415286
# n_s: 0.9699809450573025
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 101/10000 completed
# Setting cosmology
# Om_c: 0.2453963313092437
# Om_b: 0.025933385950888933
# h: 0.7115093459921867
# sigma_8: 0.9834635448884134
# n_s: 1.0831494760177147
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 102/10000 completed
# Setting cosmology
# Om_c: 0.22641792011552925
# Om_b: 0.023584497811033923
# h: 0.7354478434539267
# sigma_8: 0.9094294270438633
# n_s: 0.9870161964971228
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 103/10000 completed
# Setting cosmology
# Om_c: 0.11751201876300352
# Om_b: 0.025589690577071212
# h: 0.7723254820540082
# sigma_8: 0.9180231413639952
# n_s: 0.9643533527022534
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 104/10000 completed
# Setting cosmology
# Om_c: 0.10672582248133597
# Om_b: 0.025877053004388476
# h: 0.7626555032556781
# sigma_8: 0.9819751911149626
# n_s: 0.8573205300102267
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 105/10000 completed
# Setting cosmology
# Om_c: 0.11607031356954539
# Om_b: 0.021316785522894142
# h: 0.6918563828560331
# sigma_8: 0.9845573152462027
# n_s: 0.9104147374240716
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 106/10000 completed
# Setting cosmology
# Om_c: 0.2428260170805598
# Om_b: 0.02552404417058932
# h: 0.6519821980222941
# sigma_8: 0.8140830858076499
# n_s: 0.9378871710077417
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 107/10000 completed
# Setting cosmology
# Om_c: 0.17207773563927087
# Om_b: 0.019244154593522335
# h: 0.767762015516933
# sigma_8: 0.9572553043552877
# n_s: 0.9872609842038318
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 108/10000 completed
# Setting cosmology
# Om_c: 0.098136087697237
# Om_b: 0.021443692588108843
# h: 0.7825586862031448
# sigma_8: 0.8277665604789844
# n_s: 1.046168397025602
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 109/10000 completed
# Setting cosmology
# Om_c: 0.23211180924681613
# Om_b: 0.019397468381801317
# h: 0.660457867315189
# sigma_8: 0.9569364933003511
# n_s: 0.9266630301225538
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 110/10000 completed
# Setting cosmology
# Om_c: 0.14133136315777878
# Om_b: 0.021086274172292273
# h: 0.8194633691794269
# sigma_8: 0.8784519944231685
# n_s: 0.8591552888088742
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 111/10000 completed
# Setting cosmology
# Om_c: 0.21352551139906778
# Om_b: 0.025387983631338675
# h: 0.6727961956096817
# sigma_8: 0.8880520923688149
# n_s: 0.8434202074056509
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 112/10000 completed
# Setting cosmology
# Om_c: 0.17621379385180702
# Om_b: 0.024481463782865826
# h: 0.7106065705160629
# sigma_8: 0.8330772600928027
# n_s: 0.8643704723211302
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 113/10000 completed
# Setting cosmology
# Om_c: 0.18122271194625827
# Om_b: 0.024464828241158025
# h: 0.7964285661946671
# sigma_8: 0.9006567087921845
# n_s: 1.0844155193085618
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 114/10000 completed
# Setting cosmology
# Om_c: 0.08979239114054574
# Om_b: 0.020332483642029674
# h: 0.7408709705816352
# sigma_8: 0.9790870410972965
# n_s: 0.8407550158899617
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 115/10000 completed
# Setting cosmology
# Om_c: 0.15643952685609147
# Om_b: 0.01955280906003308
# h: 0.7336572293840304
# sigma_8: 0.8585122427325651
# n_s: 1.0645398302021825
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 116/10000 completed
# Setting cosmology
# Om_c: 0.24820901557569058
# Om_b: 0.021633283897613046
# h: 0.6454819434158473
# sigma_8: 0.819993701258975
# n_s: 0.939788988023702
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 117/10000 completed
# Setting cosmology
# Om_c: 0.1297887145143138
# Om_b: 0.021500503538130836
# h: 0.7851206723164443
# sigma_8: 0.8960029059604776
# n_s: 0.9342345641489327
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 118/10000 completed
# Setting cosmology
# Om_c: 0.09565850045446231
# Om_b: 0.02161894391616678
# h: 0.7312389951447641
# sigma_8: 0.8904786009152276
# n_s: 0.9076580039737385
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 119/10000 completed
# Setting cosmology
# Om_c: 0.2103692228679792
# Om_b: 0.023203001520523674
# h: 0.7917537994903201
# sigma_8: 0.9203727220691919
# n_s: 0.9603300369131986
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 120/10000 completed
# Setting cosmology
# Om_c: 0.20029587857121733
# Om_b: 0.019142253301323808
# h: 0.6845551948399866
# sigma_8: 0.9857036776687863
# n_s: 0.8639168066450402
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 121/10000 completed
# Setting cosmology
# Om_c: 0.09322259759471899
# Om_b: 0.022895338637191627
# h: 0.6939465136606204
# sigma_8: 0.8686978991577743
# n_s: 0.9870495783337125
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 122/10000 completed
# Setting cosmology
# Om_c: 0.08742289339754143
# Om_b: 0.01935713078231924
# h: 0.7818817061004846
# sigma_8: 0.8708053887602777
# n_s: 0.9312943879556237
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 123/10000 completed
# Setting cosmology
# Om_c: 0.22090211744073057
# Om_b: 0.02340934263296878
# h: 0.7661961913657473
# sigma_8: 0.9716828303168352
# n_s: 0.9016787516419271
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 124/10000 completed
# Setting cosmology
# Om_c: 0.22296032598409726
# Om_b: 0.021049403104655057
# h: 0.7585323281039092
# sigma_8: 0.8049968459852205
# n_s: 1.0013004566150534
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 125/10000 completed
# Setting cosmology
# Om_c: 0.15924979592139743
# Om_b: 0.02378988347365552
# h: 0.6897420047704569
# sigma_8: 0.9302148490606561
# n_s: 1.0126388990298278
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 126/10000 completed
# Setting cosmology
# Om_c: 0.0671617732547598
# Om_b: 0.024137273714299322
# h: 0.7359280900369483
# sigma_8: 0.8322813417419691
# n_s: 1.0216789234935915
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 127/10000 completed
# Setting cosmology
# Om_c: 0.09082981201249601
# Om_b: 0.022940639902793554
# h: 0.7114650533101786
# sigma_8: 0.849591300782352
# n_s: 0.8506402497717529
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 128/10000 completed
# Setting cosmology
# Om_c: 0.15494769311496503
# Om_b: 0.02128861110310896
# h: 0.7060366296723433
# sigma_8: 0.8646930553603384
# n_s: 0.9590559121548956
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 129/10000 completed
# Setting cosmology
# Om_c: 0.1282517147799797
# Om_b: 0.022353426258002386
# h: 0.7015265249086104
# sigma_8: 0.8157032458955686
# n_s: 0.9843177933775731
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 130/10000 completed
# Setting cosmology
# Om_c: 0.20793725329839868
# Om_b: 0.02285644266649268
# h: 0.6549781651465488
# sigma_8: 0.8568375944273054
# n_s: 1.0983073213102474
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 131/10000 completed
# Setting cosmology
# Om_c: 0.15552868083452173
# Om_b: 0.024482312250167934
# h: 0.7462147630886996
# sigma_8: 0.9359588977289435
# n_s: 1.0246552102905055
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 132/10000 completed
# Setting cosmology
# Om_c: 0.15600024321438044
# Om_b: 0.020306251640784673
# h: 0.7039140676611889
# sigma_8: 0.9379171197427896
# n_s: 1.0506846311888371
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 133/10000 completed
# Setting cosmology
# Om_c: 0.14721433976634016
# Om_b: 0.02614740456910577
# h: 0.745646369069096
# sigma_8: 0.8130065674936263
# n_s: 1.0246512132795038
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 134/10000 completed
# Setting cosmology
# Om_c: 0.15523284461974568
# Om_b: 0.02298779010586665
# h: 0.6893993363997886
# sigma_8: 0.9084211021010558
# n_s: 0.8441459993289047
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 135/10000 completed
# Setting cosmology
# Om_c: 0.15808393354317404
# Om_b: 0.026041051378541333
# h: 0.7417127778199522
# sigma_8: 0.9028312718754904
# n_s: 1.0509087017362502
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 136/10000 completed
# Setting cosmology
# Om_c: 0.09679083081163026
# Om_b: 0.02005208949656737
# h: 0.6670017117572804
# sigma_8: 0.8865226395760976
# n_s: 1.053931560757602
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 137/10000 completed
# Setting cosmology
# Om_c: 0.22078714552291306
# Om_b: 0.021420812834417262
# h: 0.7080601618926294
# sigma_8: 0.9505019309818539
# n_s: 1.0664437967178733
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 138/10000 completed
# Setting cosmology
# Om_c: 0.2472648183753749
# Om_b: 0.02178607920818007
# h: 0.7346020819836485
# sigma_8: 0.8390837455974343
# n_s: 1.0879929690875396
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 139/10000 completed
# Setting cosmology
# Om_c: 0.08603343615358638
# Om_b: 0.02465757103885894
# h: 0.7705650500288446
# sigma_8: 0.8743343719022811
# n_s: 0.9332910391678764
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 140/10000 completed
# Setting cosmology
# Om_c: 0.18161877940383025
# Om_b: 0.019091288244967704
# h: 0.7443329956785293
# sigma_8: 0.9020028099160275
# n_s: 0.9968412195068814
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 141/10000 completed
# Setting cosmology
# Om_c: 0.0904735186335644
# Om_b: 0.021391514581169533
# h: 0.688783897256136
# sigma_8: 0.8562361083470482
# n_s: 1.0182467655565584
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 142/10000 completed
# Setting cosmology
# Om_c: 0.16257045297864214
# Om_b: 0.02421374358413116
# h: 0.7962807049879167
# sigma_8: 0.9513833766819412
# n_s: 0.9623668286770951
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 143/10000 completed
# Setting cosmology
# Om_c: 0.18386070408676086
# Om_b: 0.01925837058370941
# h: 0.7718961790454067
# sigma_8: 0.9060858631196868
# n_s: 0.842102319906262
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 144/10000 completed
# Setting cosmology
# Om_c: 0.2096919259253246
# Om_b: 0.025530160148722156
# h: 0.7102349237189384
# sigma_8: 0.80150555636335
# n_s: 0.9250893001998741
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 145/10000 completed
# Setting cosmology
# Om_c: 0.2367550238187432
# Om_b: 0.024597605540841724
# h: 0.7731552005228287
# sigma_8: 0.9863828011009904
# n_s: 1.0346082827799512
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 146/10000 completed
# Setting cosmology
# Om_c: 0.1135697109745918
# Om_b: 0.024836787879398418
# h: 0.6550944321291509
# sigma_8: 0.9875052995863581
# n_s: 1.0439771287786985
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 147/10000 completed
# Setting cosmology
# Om_c: 0.25432268265662616
# Om_b: 0.019788119419050804
# h: 0.811276115583872
# sigma_8: 0.9474632499711368
# n_s: 0.8854870105415396
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 148/10000 completed
# Setting cosmology
# Om_c: 0.24738624670145964
# Om_b: 0.020381609170762992
# h: 0.6774814182403499
# sigma_8: 0.9867245640412092
# n_s: 1.0054110900055855
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 149/10000 completed
# Setting cosmology
# Om_c: 0.1359232674614661
# Om_b: 0.025092514265475055
# h: 0.7503520650315737
# sigma_8: 0.8816783219731085
# n_s: 0.9001096911744241
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 150/10000 completed
# Setting cosmology
# Om_c: 0.23527830596569033
# Om_b: 0.01953307361441687
# h: 0.7203258415191743
# sigma_8: 0.9925938404472623
# n_s: 0.8795151932975199
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 151/10000 completed
# Setting cosmology
# Om_c: 0.23769721999476112
# Om_b: 0.02316927913523785
# h: 0.7842650716760059
# sigma_8: 0.9205460306220823
# n_s: 1.067716959763049
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 152/10000 completed
# Setting cosmology
# Om_c: 0.2295374705800437
# Om_b: 0.023541523653262734
# h: 0.7507187595628757
# sigma_8: 0.9901638563410571
# n_s: 0.9434976253025809
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 153/10000 completed
# Setting cosmology
# Om_c: 0.2261782987973131
# Om_b: 0.026112138575865862
# h: 0.8144448975751906
# sigma_8: 0.9674206413248696
# n_s: 0.9081224331930189
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 154/10000 completed
# Setting cosmology
# Om_c: 0.05036046574201999
# Om_b: 0.019042980684878877
# h: 0.7772598076263875
# sigma_8: 0.8348762240055168
# n_s: 0.8434577504662197
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 155/10000 completed
# Setting cosmology
# Om_c: 0.16080064712673464
# Om_b: 0.01913334687448367
# h: 0.8116161246229311
# sigma_8: 0.8988360082170079
# n_s: 1.0100314648756445
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 156/10000 completed
# Setting cosmology
# Om_c: 0.18922772141362454
# Om_b: 0.02399891031362217
# h: 0.7302424988281194
# sigma_8: 0.9596924693212527
# n_s: 0.9235947583387405
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 157/10000 completed
# Setting cosmology
# Om_c: 0.15768961433754108
# Om_b: 0.019949749858402213
# h: 0.8001746808451509
# sigma_8: 0.9588429908549121
# n_s: 1.0883399373127016
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 158/10000 completed
# Setting cosmology
# Om_c: 0.06418287946694907
# Om_b: 0.021164884331386295
# h: 0.8012799595019283
# sigma_8: 0.830914168548928
# n_s: 0.9783595430908885
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 159/10000 completed
# Setting cosmology
# Om_c: 0.23591825841991132
# Om_b: 0.019576396357100567
# h: 0.7776848863046244
# sigma_8: 0.8024542907834088
# n_s: 0.8447282664750027
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 160/10000 completed
# Setting cosmology
# Om_c: 0.11443664231993128
# Om_b: 0.020031248137381472
# h: 0.707834061696943
# ...
# Run 9947/10000 completed
# Setting cosmology
# Om_c: 0.08142136060990604
# Om_b: 0.024109986228944225
# h: 0.7713078022268121
# sigma_8: 0.8203300451389381
# n_s: 1.0173154619392621
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9948/10000 completed
# Setting cosmology
# Om_c: 0.1640149114884941
# Om_b: 0.02182343063933313
# h: 0.7517466914153542
# sigma_8: 0.8509595143177705
# n_s: 0.9899180349820751
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9949/10000 completed
# Setting cosmology
# Om_c: 0.1871330257385811
# Om_b: 0.021446723282814113
# h: 0.6838235701292371
# sigma_8: 0.8229911735578822
# n_s: 0.8491470138710585
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9950/10000 completed
# Setting cosmology
# Om_c: 0.16346687750398395
# Om_b: 0.024636696109630776
# h: 0.7895341001971914
# sigma_8: 0.8533444280234768
# n_s: 0.8867162155348879
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9951/10000 completed
# Setting cosmology
# Om_c: 0.2414825293157295
# Om_b: 0.018904441963310502
# h: 0.6939856219526934
# sigma_8: 0.817305081278349
# n_s: 0.867698313204679
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9952/10000 completed
# Setting cosmology
# Om_c: 0.21276790740420365
# Om_b: 0.023355327084681177
# h: 0.7327238934137139
# sigma_8: 0.96959337230848
# n_s: 0.9696199377333651
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9953/10000 completed
# Setting cosmology
# Om_c: 0.2023889359563752
# Om_b: 0.02475055336550786
# h: 0.7947235240089339
# sigma_8: 0.8598961291896893
# n_s: 0.9078523516898656
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9954/10000 completed
# Setting cosmology
# Om_c: 0.2507820910721174
# Om_b: 0.02205848307358409
# h: 0.8160389181758086
# sigma_8: 0.8709111002551757
# n_s: 0.8944320602247153
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9955/10000 completed
# Setting cosmology
# Om_c: 0.20671463331445522
# Om_b: 0.023947926596466072
# h: 0.6809289580808932
# sigma_8: 0.8905270197210825
# n_s: 0.9450777637974261
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9956/10000 completed
# Setting cosmology
# Om_c: 0.196344129176032
# Om_b: 0.021841818830362132
# h: 0.6828724071381931
# sigma_8: 0.8921876692764557
# n_s: 0.94149710614681
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9957/10000 completed
# Setting cosmology
# Om_c: 0.14708191926251538
# Om_b: 0.025393037501834023
# h: 0.6642433086905004
# sigma_8: 0.9044275977685968
# n_s: 1.0298572523213942
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9958/10000 completed
# Setting cosmology
# Om_c: 0.13803484504525004
# Om_b: 0.019555218963262955
# h: 0.7915817197427758
# sigma_8: 0.8854669602815407
# n_s: 0.8847580350012763
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9959/10000 completed
# Setting cosmology
# Om_c: 0.17710202780694967
# Om_b: 0.02302127749306647
# h: 0.7326271891732463
# sigma_8: 0.8098423197438296
# n_s: 1.0653721442332842
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9960/10000 completed
# Setting cosmology
# Om_c: 0.13551455655951694
# Om_b: 0.02498088475117357
# h: 0.6800858586077936
# sigma_8: 0.9988791997870925
# n_s: 0.904215792314073
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9961/10000 completed
# Setting cosmology
# Om_c: 0.1327856174730267
# Om_b: 0.025403743219630865
# h: 0.6956859183805488
# sigma_8: 0.9037964260848519
# n_s: 0.8678743754059746
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9962/10000 completed
# Setting cosmology
# Om_c: 0.08200679626381661
# Om_b: 0.02036017878623544
# h: 0.645083476988042
# sigma_8: 0.9494670832610705
# n_s: 1.0011222335128769
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9963/10000 completed
# Setting cosmology
# Om_c: 0.09642714758158522
# Om_b: 0.023804562156953972
# h: 0.7187812422709762
# sigma_8: 0.9370897032125574
# n_s: 1.0223122313290343
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9964/10000 completed
# Setting cosmology
# Om_c: 0.2350717820614482
# Om_b: 0.023119170869367444
# h: 0.693262518449688
# sigma_8: 0.9496088469028576
# n_s: 1.0904115851253269
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9965/10000 completed
# Setting cosmology
# Om_c: 0.2334431849018082
# Om_b: 0.023619314925371053
# h: 0.8138557077385405
# sigma_8: 0.9466024920755668
# n_s: 0.9015317309173588
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9966/10000 completed
# Setting cosmology
# Om_c: 0.17821557881700661
# Om_b: 0.02142422441246651
# h: 0.8154079673988629
# sigma_8: 0.993947857890158
# n_s: 1.0259025039532532
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9967/10000 completed
# Setting cosmology
# Om_c: 0.1874238173295299
# Om_b: 0.025591566594047734
# h: 0.7340515848679944
# sigma_8: 0.8513135197969973
# n_s: 1.0170380696163381
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9968/10000 completed
# Setting cosmology
# Om_c: 0.22675861774669143
# Om_b: 0.01891382804342692
# h: 0.6653352403345675
# sigma_8: 0.8684233304270627
# n_s: 1.0003822166225187
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9969/10000 completed
# Setting cosmology
# Om_c: 0.19786603486606097
# Om_b: 0.019234691570255324
# h: 0.6579430772584411
# sigma_8: 0.8744759479334809
# n_s: 0.9654793863810487
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9970/10000 completed
# Setting cosmology
# Om_c: 0.15483564114958587
# Om_b: 0.021138411773058155
# h: 0.6922710345936767
# sigma_8: 0.837813349688127
# n_s: 0.9145264921540974
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9971/10000 completed
# Setting cosmology
# Om_c: 0.18589715745133084
# Om_b: 0.021445179236564544
# h: 0.7247544978306549
# sigma_8: 0.824238563203108
# n_s: 0.997200907214076
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9972/10000 completed
# Setting cosmology
# Om_c: 0.21440842354240885
# Om_b: 0.024351844495716014
# h: 0.657253839299296
# sigma_8: 0.878331689154921
# n_s: 0.8999202481512386
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9973/10000 completed
# Setting cosmology
# Om_c: 0.10666027130076511
# Om_b: 0.02620608370986195
# h: 0.6650928302195681
# sigma_8: 0.9870749765878262
# n_s: 0.9853550727392275
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9974/10000 completed
# Setting cosmology
# Om_c: 0.0930084656669123
# Om_b: 0.02560522113743085
# h: 0.6423367760006489
# sigma_8: 0.9528487651583104
# n_s: 0.8804384839984306
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9975/10000 completed
# Setting cosmology
# Om_c: 0.19543405193259034
# Om_b: 0.02026757815874105
# h: 0.6540783288501366
# sigma_8: 0.9919695627317752
# n_s: 0.8769895201838059
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9976/10000 completed
# Setting cosmology
# Om_c: 0.25362304900278954
# Om_b: 0.022989898799083065
# h: 0.775765758779354
# sigma_8: 0.857796396003459
# n_s: 1.0537773304223705
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9977/10000 completed
# Setting cosmology
# Om_c: 0.14812687105319272
# Om_b: 0.021785305543207317
# h: 0.7793009113063953
# sigma_8: 0.8510544047866354
# n_s: 0.9236874951148912
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9978/10000 completed
# Setting cosmology
# Om_c: 0.23556982492059886
# Om_b: 0.025600116469191032
# h: 0.7930577678352512
# sigma_8: 0.9656376547831349
# n_s: 0.9959252134819704
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9979/10000 completed
# Setting cosmology
# Om_c: 0.10555894778638822
# Om_b: 0.022514926468915453
# h: 0.7182850812347269
# sigma_8: 0.9114971237876425
# n_s: 1.0747856059679055
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9980/10000 completed
# Setting cosmology
# Om_c: 0.06207471517399615
# Om_b: 0.0229179380012683
# h: 0.6608557785954863
# sigma_8: 0.8437283871027333
# n_s: 1.0346135095262232
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9981/10000 completed
# Setting cosmology
# Om_c: 0.17498519229275813
# Om_b: 0.018889843707528997
# h: 0.7692513713155908
# sigma_8: 0.9498206136014945
# n_s: 0.8839919834698999
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9982/10000 completed
# Setting cosmology
# Om_c: 0.057729901214991504
# Om_b: 0.021002336158713907
# h: 0.7472991287677202
# sigma_8: 0.9261972683705085
# n_s: 0.9231797756002369
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9983/10000 completed
# Setting cosmology
# Om_c: 0.12074394926860146
# Om_b: 0.025251680014667655
# h: 0.737329349650871
# sigma_8: 0.8832131915733609
# n_s: 0.9051015163212467
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9984/10000 completed
# Setting cosmology
# Om_c: 0.20526563810712173
# Om_b: 0.022910674425552842
# h: 0.7610746696956461
# sigma_8: 0.8267469796940768
# n_s: 0.9900944188169203
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9985/10000 completed
# Setting cosmology
# Om_c: 0.09094184488778512
# Om_b: 0.020062571727415126
# h: 0.6955312987637746
# sigma_8: 0.8386613538771673
# n_s: 0.9175926455550706
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9986/10000 completed
# Setting cosmology
# Om_c: 0.17606576408830826
# Om_b: 0.02567621149334822
# h: 0.7950418420228582
# sigma_8: 0.9546072419023983
# n_s: 0.8540933013698979
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9987/10000 completed
# Setting cosmology
# Om_c: 0.1530540275419468
# Om_b: 0.022857733959961914
# h: 0.7104754842399132
# sigma_8: 0.8091764045144869
# n_s: 0.9784362476477857
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9988/10000 completed
# Setting cosmology
# Om_c: 0.20411499321307386
# Om_b: 0.020798077011040618
# h: 0.7057460119660972
# sigma_8: 0.8332808831246429
# n_s: 0.971450917439384
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9989/10000 completed
# Setting cosmology
# Om_c: 0.1770154690009666
# Om_b: 0.018925952001442564
# h: 0.8197005733219036
# sigma_8: 0.8126894431373475
# n_s: 0.902684824539103
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9990/10000 completed
# Setting cosmology
# Om_c: 0.18395364852468976
# Om_b: 0.0238827468400097
# h: 0.6540513897078033
# sigma_8: 0.9822123929674553
# n_s: 1.0051033645216938
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9991/10000 completed
# Setting cosmology
# Om_c: 0.21522683433816253
# Om_b: 0.02171297341968956
# h: 0.735716624068238
# sigma_8: 0.9528967112525483
# n_s: 1.0687009138647208
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9992/10000 completed
# Setting cosmology
# Om_c: 0.2367112494461439
# Om_b: 0.022718095130663314
# h: 0.6685927621951884
# sigma_8: 0.8361293565757814
# n_s: 0.8438928032399818
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9993/10000 completed
# Setting cosmology
# Om_c: 0.09071975312238116
# Om_b: 0.02528801834064937
# h: 0.7244574193061595
# sigma_8: 0.8005255312433877
# n_s: 1.0543682461591917
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9994/10000 completed
# Setting cosmology
# Om_c: 0.0985871907332906
# Om_b: 0.024352965270699085
# h: 0.7784778812046788
# sigma_8: 0.8879698222085606
# n_s: 0.9933747459647173
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9995/10000 completed
# Setting cosmology
# Om_c: 0.098527941239069
# Om_b: 0.022840568000611725
# h: 0.8073802856346501
# sigma_8: 0.9710824769032821
# n_s: 0.8560721881827569
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9996/10000 completed
# Setting cosmology
# Om_c: 0.09488161571287226
# Om_b: 0.023032658017474977
# h: 0.7875229819343617
# sigma_8: 0.9132414144434373
# n_s: 1.0054941309732752
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9997/10000 completed
# Setting cosmology
# Om_c: 0.2528295656372632
# Om_b: 0.02470111347818562
# h: 0.6605250052894965
# sigma_8: 0.9115877585754786
# n_s: 1.0903302094273641
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9998/10000 completed
# Setting cosmology
# Om_c: 0.12717818506600198
# Om_b: 0.020227566961111564
# h: 0.8113130569258131
# sigma_8: 0.9335029640681045
# n_s: 0.9179942909793791
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 9999/10000 completed
# Setting cosmology
# Om_c: 0.17883443685573214
# Om_b: 0.023928223799970158
# h: 0.7810884759724342
# sigma_8: 0.8695924301807886
# n_s: 1.0733496934321602
# Also setting linear matter power spectrum
# Setting halo mass function
# Setting halo bias function
# Setting concentration mass relation
# Run 10000/10000 completed

# %% [markdown]
# ## Saving generated data

# %%
# Funktion, die rekursiv alle np.ndarrays in Listen umwandelt
def convert_to_serializable(obj):
    if isinstance(obj, np.ndarray):
        return obj.tolist()  # Umwandlung in eine Python-Liste
    elif isinstance(obj, list):
        return [convert_to_serializable(item) for item in obj]  # Rekursive Umwandlung der Listenelemente
    elif isinstance(obj, dict):
        return {key: convert_to_serializable(value) for key, value in obj.items()}  # Rekursive Umwandlung der Dictionary-Werte
    else:
        return obj  # Für alle anderen Typen keine Änderung

# Konvertiere alle numpy.ndarrays in data_array
data_array_serializable = [convert_to_serializable(sublist) for sublist in data_array]

# Anzahl der generierten Daten
num_data_points = len(data_array_serializable)

# Verzeichnis für die gespeicherten Daten
data_dir = "../Data/"
os.makedirs(data_dir, exist_ok=True)

# Erzeuge einen einzigartigen Dateinamen mit Zeitstempel
timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
data_fn = f"{data_dir}/GeneratedData_{num_data_points}_{timestamp}.json"

# Speichern der Daten
with open(data_fn, "w") as json_file:
    json.dump(data_array_serializable, json_file, indent=4)

print(f"Daten erfolgreich gespeichert in: {data_fn}")
# Out:
# Daten erfolgreich gespeichert in: ../Data//GeneratedData_10000_2025-04-22_13-00-44.json

# %% [markdown]
# ## Saving related parameter

# %%
para_fn = f"{data_dir}/Parameter_{num_data_points}_{timestamp}.json"
# Speichern der Daten
with open(para_fn, "w") as json_file:
    json.dump(cosmo_samples, json_file, indent=4)

print(f"Daten erfolgreich gespeichert in: {data_fn}")
# Out:
# Daten erfolgreich gespeichert in: ../Data//GeneratedData_10000_2025-04-22_13-00-44.json
